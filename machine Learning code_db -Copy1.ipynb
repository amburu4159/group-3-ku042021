# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("merged_data.csv")
df.head()
# Out:
#    Unnamed: 0   Case Number                        Crash Description  \
# 0           0  201901174219                       Stratum 10 - Other
# 1           1  201901176655          Stratum 6 - LMY PV Minor Injury
# 2          25  201901176667         Stratum 8 - NLMY PV Minor Injury
# 3          33  201901176694  Stratum 9 - LMY PV No Injuries in Crash
# 4          34  201901176702          Stratum 6 - LMY PV Minor Injury
#
#                                               Region  Urban or City    Month  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              2  January
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              2  January
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              1  January
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              1  January
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              1  January
#
#      Alcohol Involved?               Harmful Event Weather  Hour of Day  ...  \
# 0  No Alcohol Involved                        Curb  Cloudy            8  ...
# 1  Reported as Unknown  Motor Vehicle In-Transport   Clear            2  ...
# 2     Alcohol Involved  Motor Vehicle In-Transport   Clear            5  ...
# 3  No Alcohol Involved        Traffic Sign Support   Clear            4  ...
# 4  No Alcohol Involved  Motor Vehicle In-Transport   Clear            9  ...
#
#                                Make/Model of Vehicle Year of Vehicle  \
# 0                                        Ford Ranger            2006
# 1  Dodge Dart (2013 on. See model 001 for 1960-19...            2015
# 2                               Nissan/Datsun Xterra            2000
# 3                                       Mazda Mazda3            2016
# 4                                     Toyota Sequoia            2001
#
#           Speed                         Type of Distraction Number of Persons  \
# 0  Not Reported                              Not Distracted                 1
# 1  Not Reported                                Not Reported                 1
# 2       040 MPH  Inattention (Inattentive), Details Unknown                 1
# 3       040 MPH                              Not Distracted                 1
# 4       005 MPH           Reported as Unknown if Distracted                 1
#
#   Gender  Age Air Bag Deployment               DRINKINGNAME  \
# 0   Male   39       Not Deployed  No (Alcohol Not Involved)
# 1   Male   20       Not Deployed               Not Reported
# 2   Male   37       Not Deployed     Yes (Alcohol Involved)
# 3   Male   26    Deployed- Front  No (Alcohol Not Involved)
# 4   Male   56       Not Deployed  No (Alcohol Not Involved)
#
#               Restraint Usage
# 0  Shoulder and Lap Belt Used
# 1  Shoulder and Lap Belt Used
# 2  Shoulder and Lap Belt Used
# 3    None Used/Not Applicable
# 4  Shoulder and Lap Belt Used
#
# [5 rows x 25 columns]

# %%
df.sort_values(by= ['Age'], inplace= True)
df.head()
# Out:
#        Unnamed: 0   Case Number                         Crash Description  \
# 12554      140102  201901486823  Stratum 2 - Not a MV Occupant Any Injury
# 36515      414297  201901901797        Stratum 5 - NLMY PV Serious Injury
# 32931      373546  201901842299  Stratum 2 - Not a MV Occupant Any Injury
# 21678      246115  201901643280         Stratum 4 - LMY PV Serious Injury
# 41833      474496  201901990843  Stratum 2 - Not a MV Occupant Any Injury
#
#                                                   Region  Urban or City  \
# 12554     Northeast (PA, NJ, NY, NH, VT, RI, MA, ME, CT)              1
# 36515  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...              1
# 32931  West (MT, ID, WA, OR, CA, NV, NM, AZ, UT, CO, ...              1
# 21678     Northeast (PA, NJ, NY, NH, VT, RI, MA, ME, CT)              1
# 41833  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...              1
#
#            Month    Alcohol Involved?               Harmful Event Weather  \
# 12554   February  Reported as Unknown                  Pedestrian   Clear
# 36515  September  No Alcohol Involved  Motor Vehicle In-Transport   Clear
# 32931  September  Reported as Unknown                Pedalcyclist   Clear
# 21678        May     Alcohol Involved  Motor Vehicle In-Transport    Rain
# 41833  September  Reported as Unknown                  Pedestrian   Clear
#
#        Hour of Day  ...                         Make/Model of Vehicle  \
# 12554            9  ...             Unknown Make Unknown (automobile)
# 36515           13  ...                      Honda Civic/CRX, del Sol
# 32931           12  ...  Chevrolet C, K, R, V-series pickup/Silverado
# 21678           20  ...                     Hyundai Unknown (HYUNDAI)
# 41833           15  ...                                  KIA Sportage
#
#       Year of Vehicle         Speed  \
# 12554            9999  Not Reported
# 36515            2012       018 MPH
# 32931            9999  Not Reported
# 21678            2007  Not Reported
# 41833            2011       010 MPH
#
#                               Type of Distraction Number of Persons  \
# 12554                     Distraction/Inattention                 1
# 36515  Inattention (Inattentive), Details Unknown                 1
# 32931                              Not Distracted                 1
# 21678                                Not Reported                 1
# 41833                              Not Distracted                 1
#
#              Gender  Age            Air Bag Deployment  \
# 12554  Not Reported    0  Not a Motor Vehicle Occupant
# 36515        Female    0               Deployed- Front
# 32931          Male    0  Not a Motor Vehicle Occupant
# 21678          Male    0                  Not Deployed
# 41833          Male    0  Not a Motor Vehicle Occupant
#
#                     DRINKINGNAME               Restraint Usage
# 12554               Not Reported  Not a Motor Vehicle Occupant
# 36515               Not Reported    Shoulder and Lap Belt Used
# 32931  No (Alcohol Not Involved)  Not a Motor Vehicle Occupant
# 21678               Not Reported    Shoulder and Lap Belt Used
# 41833               Not Reported  Not a Motor Vehicle Occupant
#
# [5 rows x 25 columns]

# %%
df.
