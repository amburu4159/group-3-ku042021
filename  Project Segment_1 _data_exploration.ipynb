# %%
import pandas as pd
import numpy as np

# %%
# Files to Load
accident_data = "Resources/accident.csv"
distract_data = "Resources/distract.csv"
person_data = "Resources/person.csv"
vehicle_data = "Resources/vehicle.csv"

# %%
# read data into df
accident_data_df = pd.read_csv(accident_data, low_memory=False)
distract_data_df = pd.read_csv(distract_data, low_memory=False)
person_data_df = pd.read_csv(person_data, low_memory=False)
vehicle_data_df = pd.read_csv(vehicle_data,low_memory=False)

# %%
# check accident data
accident_data_df.head(5)
# Out:
#         CASENUM  STRATUM                              STRATUMNAME  REGION  \
# 0  201901174219       10                       Stratum 10 - Other       3
# 1  201901176655        6          Stratum 6 - LMY PV Minor Injury       3
# 2  201901176667        8         Stratum 8 - NLMY PV Minor Injury       3
# 3  201901176694        9  Stratum 9 - LMY PV No Injuries in Crash       3
# 4  201901176702        6          Stratum 6 - LMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
#
#    URBANICITY URBANICITYNAME  ...  LGTCON_IM   LGTCON_IMNAME  WEATHR_IM  \
# ...

# %%
# check distract data
distract_data_df.head(5)
# Out:
#         CASENUM  VEH_NO  STRATUM                       STRATUMNAME  REGION  \
# 0  201901174219       1       10                Stratum 10 - Other       3
# 1  201901176655       1        6   Stratum 6 - LMY PV Minor Injury       3
# 2  201901176655       2        6   Stratum 6 - LMY PV Minor Injury       3
# 3  201901176667       1        8  Stratum 8 - NLMY PV Minor Injury       3
# 4  201901176667       2        8  Stratum 8 - NLMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
#
#    URBANICITY URBANICITYNAME  MDRDSTRD  \
# ...

# %%
# check person data
person_data_df.head(5)
# Out:
#         CASENUM  VE_FORMS  VEH_NO  PER_NO  STRATUM  \
# 0  201901174219         1       1       1       10
# 1  201901176655         2       1       1        6
# 2  201901176655         2       1       2        6
# 3  201901176655         2       1       3        6
# 4  201901176655         2       1       4        6
#
#                        STRATUMNAME  REGION  \
# 0               Stratum 10 - Other       3
# 1  Stratum 6 - LMY PV Minor Injury       3
# 2  Stratum 6 - LMY PV Minor Injury       3
# 3  Stratum 6 - LMY PV Minor Injury       3
# 4  Stratum 6 - LMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  ...  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144  ...
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135  ...
# ...

# %%
# check vehicle data
vehicle_data_df.head(5)
# Out:
#         CASENUM  VEH_NO  STRATUM                       STRATUMNAME  REGION  \
# 0  201901174219       1       10                Stratum 10 - Other       3
# 1  201901176655       1        6   Stratum 6 - LMY PV Minor Injury       3
# 2  201901176655       2        6   Stratum 6 - LMY PV Minor Injury       3
# 3  201901176667       1        8  Stratum 8 - NLMY PV Minor Injury       3
# 4  201901176667       2        8  Stratum 8 - NLMY PV Minor Injury       3
#
#                                           REGIONNAME  PSU    PJ  PSU_VAR  \
# 0  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
#
#    URBANICITY  ... VEVENT_IM               VEVENT_IMNAME  PCRASH1_IM  \
# ...

# %%
# Remove rows that have at least 1 null value.
accident_data_df.dropna()
# Out:
#             CASENUM  STRATUM                              STRATUMNAME  REGION  \
# 0      201901174219       10                       Stratum 10 - Other       3
# 1      201901176655        6          Stratum 6 - LMY PV Minor Injury       3
# 2      201901176667        8         Stratum 8 - NLMY PV Minor Injury       3
# 3      201901176694        9  Stratum 9 - LMY PV No Injuries in Crash       3
# 4      201901176702        6          Stratum 6 - LMY PV Minor Injury       3
# ...             ...      ...                                      ...     ...
# 54404  201902285920        8         Stratum 8 - NLMY PV Minor Injury       4
# 54405  201902285944        7             Stratum 7 - M/H Truck or Bus       2
# 54406  201902285945       10                       Stratum 10 - Other       2
# 54407  201902285953        9  Stratum 9 - LMY PV No Injuries in Crash       2
# 54408  201902285965        6          Stratum 6 - LMY PV Minor Injury       2
#
# ...

# %%
accident_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54409 entries, 0 to 54408
# Data columns (total 88 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CASENUM         54409 non-null  int64
#  1   STRATUM         54409 non-null  int64
#  2   STRATUMNAME     54409 non-null  object
#  3   REGION          54409 non-null  int64
#  4   REGIONNAME      54409 non-null  object
#  5   PSU             54409 non-null  int64
#  6   PJ              54409 non-null  int64
#  7   PSU_VAR         54409 non-null  int64
#  8   URBANICITY      54409 non-null  int64
#  9   URBANICITYNAME  54409 non-null  object
#  10  VE_TOTAL        54409 non-null  int64
#  11  VE_FORMS        54409 non-null  int64
#  12  PVH_INVL        54409 non-null  int64
#  13  PEDS            54409 non-null  int64
#  14  PERMVIT         54409 non-null  int64
#  15  PERNOTMVIT      54409 non-null  int64
#  16  NUM_INJ         54409 non-null  int64
# ...

# %%
# Remove rows that have at least 1 null value.
accident_data_df.dropna()
# Out:
#             CASENUM  STRATUM                              STRATUMNAME  REGION  \
# 0      201901174219       10                       Stratum 10 - Other       3
# 1      201901176655        6          Stratum 6 - LMY PV Minor Injury       3
# 2      201901176667        8         Stratum 8 - NLMY PV Minor Injury       3
# 3      201901176694        9  Stratum 9 - LMY PV No Injuries in Crash       3
# 4      201901176702        6          Stratum 6 - LMY PV Minor Injury       3
# ...             ...      ...                                      ...     ...
# 54404  201902285920        8         Stratum 8 - NLMY PV Minor Injury       4
# 54405  201902285944        7             Stratum 7 - M/H Truck or Bus       2
# 54406  201902285945       10                       Stratum 10 - Other       2
# 54407  201902285953        9  Stratum 9 - LMY PV No Injuries in Crash       2
# 54408  201902285965        6          Stratum 6 - LMY PV Minor Injury       2
#
# ...
